# %% [markdown]
# # Exercises: Control Flow in Python
#
# This notebook contains 5 exercises designed to help you practice using:
#
# - `if` statements for conditional execution
# - `for` loops for iteration
# - `while` loops for repeated actions
#
# Each exercise builds on core concepts and challenges your understanding of Python syntax and logic. Read the prompt for each exercise, fill in the code, and run the cell to check your solution.
#
# ---

# %% [markdown]
# ## Exercise 1: Check Even or Odd
#
# **Objective**: Write a program that checks whether a number is even or odd using an `if` statement.
#
# **Task**:
# - Ask the user to input a number.
# - Print `Even` if the number is divisible by 2, otherwise print `Odd`.
#
# **Hint**: Use the modulus operator (`%`) to determine divisibility.

# %%
# Exercise 1: Check Even or Odd

# Use an if-else statement to check if the number is even or odd
# Out:
# Enter a number:  4
# Even

# %% [markdown]
# ## Exercise 2: Sum of Numbers
#
# **Objective**: Use a `for` loop to calculate the sum of all numbers in a list.
#
# **Task**:
# - Define a list of numbers: `[5, 10, 15, 20, 25]`.
# - Use a `for` loop to calculate and print the sum of all the numbers.
#
# **Hint**: Initialize a variable to store the sum before the loop.

# %%
# Exercise 2: Sum of Numbers


# Use a for loop to calculate the sum

# %% [markdown]
# ## Exercise 3: Find the Maximum
#
# **Objective**: Use a `for` loop to find the largest number in a list.
#
# **Task**:
# - Define a list of numbers: `[12, 45, 78, 34, 23, 89, 56]`.
# - Use a `for` loop to find and print the largest number.
#
# **Hint**: Start by assuming the first number is the largest, then compare it with the rest.

# %%
# Exercise 3: Find the Maximum

# Use a for loop to find the largest number

# %% [markdown]
# ## Exercise 4: Countdown Timer
#
# **Objective**: Use a `while` loop to create a countdown timer.
#
# **Task**:
# - Ask the user to input a starting number.
# - Use a `while` loop to print a countdown from that number to 0.
# - Print `Blast off!` when the countdown is complete.
#
# **Hint**: Decrement the number in each iteration of the loop.

# %%
# Exercise 4: Countdown Timer


# Use a while loop for the countdown

# %% [markdown]
# ## Exercise 5: Multiplication Table
#
# **Objective**: Use nested `for` loops to print a multiplication table.
#
# **Task**:
# - Use two nested `for` loops to generate a multiplication table from 1 to 5.
# - Format the output so that each number is separated by a tab (`\t`).
#
# **Hint**: Use the `end` parameter in `print()` to format the table.

# %%
# Exercise 5: Multiplication Table

# %% [markdown]
# ## Summary
# In these exercises, you practiced using:
#
# - `if` statements to handle conditions.
# - `for` loops for iterating over sequences.
# - `while` loops for repeating actions until a condition is met.
#
# These concepts are fundamental to Python programming and provide the foundation for solving more complex problems. Great work!
